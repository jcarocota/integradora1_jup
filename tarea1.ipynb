# %% [markdown]
# Tarea 1. Programar el siguiente código considerando una red con una capa de
# entrada y una de salida, ambas con 1 neurona

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from keras import Input

# %%
centigrados = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit  = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# %%
capa = tf.keras.layers.Dense(units=1, input_shape=[1])
modelo = tf.keras.Sequential([capa])

# %%
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
print("Comenzando entrenamiento...")
historial = modelo.fit(centigrados, fahrenheit, epochs=1000, verbose=False)
print("Modelo entrenado")
# Out:
# Comenzando entrenamiento...
# Modelo entrenado

# %%
# Curva de pérdida
plt.xlabel("# Época")
plt.ylabel("Magnitud de pérdida")
plt.plot(historial.history["loss"])
plt.show()

# %%
print("Hagamos una predicción!")
resultado = modelo.predict(np.array([[50.0]], dtype=float), verbose=0)
print("El resultado es:", resultado, "fahrenheit")
# Out:
# Hagamos una predicción!
# El resultado es: [[121.81831]] fahrenheit

# %% [markdown]
# Se tuvo que adaptar el predict ya que en versiones anteriores de TensorFlow no se necesitaba el parámetro verbose.

# %%
print("Variables internas del modelo (peso, sesgo):")
print(capa.get_weights())
# Out:
# Variables internas del modelo (peso, sesgo):
# [array([[1.7984353]], dtype=float32), array([31.896542], dtype=float32)]
